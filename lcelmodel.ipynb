# %%
import os 
from dotenv import load_dotenv
load_dotenv()

import openai 

groq_api_key=os.getenv("GROQ_API_KEY")

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Obtaining dependency information for langchain_groq from https://files.pythonhosted.org/packages/e8/11/71a35db3ed8ac2c7129eb69f0d590e4961be67ac84b6c470fc097d0dd7c8/langchain_groq-1.1.2-py3-none-any.whl.metadata
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Obtaining dependency information for groq<1.0.0,>=0.30.0 from https://files.pythonhosted.org/packages/5f/d6/645a081750e43f858b7d09dce5d8e1e76cf11e7e4bdba81252e04f78963d/groq-0.37.1-py3-none-any.whl.metadata
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain_groq) (1.3.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.13.3)
# Requirement already satisfied: sniffio in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.0.14)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.7.38)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.13)
# Requirement already satisfied: certifi in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\gupta\downloads\llm_lcel\lcelvenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.6.3)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ---------------------------------------- 0.0/137.5 kB ? eta -:--:--
#    ----------- ---------------------------- 41.0/137.5 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 137.5/137.5 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: groq, langchain_groq
# Successfully installed groq-0.37.1 langchain_groq-1.1.2
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile",groq_api_key=groq_api_key)

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following English text to French"),
    HumanMessage(content="Hello, how are you?")
]

response = model.invoke(messages)
print(response.content)

result=model.invoke(messages)
# Out:
# Bonjour, comment allez-vous ?

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour, comment allez-vous ?'

# %%
#using lcel chain the components
chain=model | parser
chain.invoke(messages)
# Out:
# 'Bonjour, comment vas-tu ?'
